# %% [markdown]
# # Joining Data in SQL

# %%
# !conda install -yc conda-forge ipython-sql
# Out:
# Collecting package metadata (current_repodata.json): done
# Solving environment: done
#
# # All requested packages already installed.

# %%
# %%capture
# %load_ext sql
# %sql sqlite:///factbook-join.db

# %% [markdown]
# In this mission, we're going to be using a version of the CIA World Factbook (Factbook) database from the guided project from the SQL Fundamentals course. To refresh your memory, this database had one table called facts, where each row represented a country from the Factbook.

# %%
# %%sql
# Select * from facts
# limit 5;
# Out:
#  * sqlite:///factbook-join.db
#    sqlite:///factbook.db
# Done.
# [(1, 'af', 'Afghanistan', 652230, 652230, 0, 32564342, 2.32, 38.57, 13.89, 1.51),
#  (2, 'al', 'Albania', 28748, 27398, 1350, 3029278, 0.3, 12.92, 6.58, 3.3),
#  (3, 'ag', 'Algeria', 2381741, 2381741, 0, 39542166, 1.84, 23.67, 4.31, 0.92),
#  (4, 'an', 'Andorra', 468, 468, 0, 85580, 0.12, 8.13, 6.96, 0.0),
#  (5, 'ao', 'Angola', 1246700, 1246700, 0, 19625353, 2.78, 38.78, 11.49, 0.46)]

# %% [markdown]
# ### Inner joins

# %% [markdown]
# In addition to the facts table we've added a new table, called cities which contains information on major urban areas from countries in the Factbook (for the rest of this mission, we'll use the word 'cities' to mean the same as 'major urban areas'). Let's take a look at
# a description of what each column represents:
#
# - id - A unique ID for each city.
# - name - The name of the city.
# - population - The population of the city.
# - capital - Whether the city is a capital city: 1 if it is, 0 if it isn't.
# - facts_id - The ID of the country, from the facts table.

# %%
# %%sql
# Select * from cities
# limit 5;
# Out:
#  * sqlite:///factbook-join.db
#    sqlite:///factbook.db
# Done.
# [(1, 'Oranjestad', 37000, 1, '216'),
#  (2, "Saint John'S", 27000, 1, '6'),
#  (3, 'Abu Dhabi', 942000, 1, '184'),
#  (4, 'Dubai', 1978000, 0, '184'),
#  (5, 'Sharjah', 983000, 0, '184')]

# %% [markdown]
# The last column is of particular interest to us, as it is a column of data that also exists in our original facts table. This link between tables is important as it's used to combine the data in our queries.

# %% [markdown]
# The most common way to join data using SQL is using an inner join. The syntax for an inner join is:
#
# SELECT [column_names] FROM [table_name_one]
#
# INNER JOIN [table_name_two] ON [join_constraint];
#
# The inner join clause is made up of two parts:
#
# - INNER JOIN, which tells the SQL engine the name of the table you wish to join in your query, and that you wish to use an inner join.
# - ON, which tells the SQL engine what columns to use to join the two tables.
#
# Joins are usually used in a query after the FROM clause. Let's look at a basic inner join where we combine the data from both of our tables.

# %%
# %%sql
# SELECT * FROM facts
# INNER JOIN cities ON cities.facts_id = facts.id
# LIMIT 5;
# Out:
#  * sqlite:///factbook-join.db
#    sqlite:///factbook.db
# Done.
# [(216, 'aa', 'Aruba', 180, 180, 0, 112162, 1.33, 12.56, 8.18, 8.92, 1, 'Oranjestad', 37000, 1, '216'),
#  (6, 'ac', 'Antigua and Barbuda', 442, 442, 0, 92436, 1.24, 15.85, 5.69, 2.21, 2, "Saint John'S", 27000, 1, '6'),
#  (184, 'ae', 'United Arab Emirates', 83600, 83600, 0, 5779760, 2.58, 15.43, 1.97, 12.36, 3, 'Abu Dhabi', 942000, 1, '184'),
#  (184, 'ae', 'United Arab Emirates', 83600, 83600, 0, 5779760, 2.58, 15.43, 1.97, 12.36, 4, 'Dubai', 1978000, 0, '184'),
#  (184, 'ae', 'United Arab Emirates', 83600, 83600, 0, 5779760, 2.58, 15.43, 1.97, 12.36, 5, 'Sharjah', 983000, 0, '184')]

# %% [markdown]
# - INNER JOIN cities - This tells the SQL engine that we wish to join the cities table to our query using an inner join.
# - ON cities.facts_id = facts.id - This tells the SQL engine which columns to use when joining the data, following the syntax table_name.column_name.
#
# This query gives us all columns from both tables and every row where there is a match between the `id` column from `facts` and the `facts_id` from `cities`, limited to the first 5 rows.
#
# An inner join works by including only rows from each table that have a match as specified using the ON clause
#
# Our inner join will include:
#
# - Rows from the cities table that have a cities.facts_id that matches a facts.id from facts.
# Our inner join will not include:
#
# - Rows from the cities table that have a cities.facts_id that doesn't match any facts.id from facts.
# - Rows from the facts table that have a facts.id that doesn't match any cities.facts_id from cities.
#
# ### Aliases
#
# In the SQL fundamentals course, we learned how to use `aliases` to specify custom names for columns, eg:
#
# SELECT AVG(population) AS AVERAGE_POPULATION
#
# We can also create aliases for table names, which makes queries with joins easier to both read and write. Instead of:
#
# SELECT * FROM facts
# INNER JOIN cities ON cities.facts_id = facts.id
#
# We can write:
#
# SELECT * FROM facts AS f
# INNER JOIN cities AS c ON c.facts_id = f.id
#
# Just like with column names, using AS is optional. We can get the same result by writing:
#
# SELECT * FROM facts f
# INNER JOIN cities c ON c.facts_id = f.id
#
# We can also combine aliases with wildcards - for instance, using the aliases created above, c.* would give us all columns from the table cities.
#
# While our query from the previous screen included both columns from the ON clause, we don't need to use either column from our ON clause in our final list of columns. This is useful as it means we can show only the information we're interested in, rather than having to include the two join columns every time.

# %%
# %%sql
# SELECT c.*, f.name AS country_name FROM facts AS f
# INNER JOIN cities AS c ON c.facts_id = f.id
# LIMIT 5;
# Out:
#  * sqlite:///factbook-join.db
#    sqlite:///factbook.db
# Done.
# [(1, 'Oranjestad', 37000, 1, '216', 'Aruba'),
#  (2, "Saint John'S", 27000, 1, '6', 'Antigua and Barbuda'),
#  (3, 'Abu Dhabi', 942000, 1, '184', 'United Arab Emirates'),
#  (4, 'Dubai', 1978000, 0, '184', 'United Arab Emirates'),
#  (5, 'Sharjah', 983000, 0, '184', 'United Arab Emirates')]

# %% [markdown]
# Write a query that:
# - Joins cities to facts using an INNER JOIN.
# - Uses aliases for table names.
# - Includes, in order:
#     - All columns from cities.
#     - The name column from facts aliased to country_name.
# - Includes only the first 5 rows.

# %%
# %%sql
# SELECT c.*, f.name AS country_name
# FROM facts AS f
# INNER JOIN cities AS c ON c.facts_id = f.id
# LIMIT 5;
# Out:
#  * sqlite:///factbook-join.db
#    sqlite:///factbook.db
# Done.
# [(1, 'Oranjestad', 37000, 1, '216', 'Aruba'),
#  (2, "Saint John'S", 27000, 1, '6', 'Antigua and Barbuda'),
#  (3, 'Abu Dhabi', 942000, 1, '184', 'United Arab Emirates'),
#  (4, 'Dubai', 1978000, 0, '184', 'United Arab Emirates'),
#  (5, 'Sharjah', 983000, 0, '184', 'United Arab Emirates')]

# %% [markdown]
# Write a query that uses an INNER JOIN to join the two tables in your query and returns, in order:
# - A column of country names, called country.
# - A column of each country's capital city, called capital_city

# %%
# %%sql
# SELECT f.name country, c.name capital_city
# FROM cities c
# INNER JOIN facts f on f.id = c.facts_id
# WHERE c.capital = 1;
# Out:
#  * sqlite:///factbook-join.db
#    sqlite:///factbook.db
# Done.
# [('Aruba', 'Oranjestad'),
#  ('Antigua and Barbuda', "Saint John'S"),
#  ('United Arab Emirates', 'Abu Dhabi'),
#  ('Afghanistan', 'Kabul'),
#  ('Algeria', 'Algiers'),
#  ('Azerbaijan', 'Baku'),
#  ('Albania', 'Tirana'),
#  ('Armenia', 'Yerevan'),
#  ('Andorra', 'Andorra La Vella'),
#  ('Angola', 'Luanda'),
#  ('American Samoa', 'Pago Pago'),
#  ('Argentina', 'Buenos Aires'),
#  ('Australia', 'Canberra'),
#  ('Austria', 'Vienna'),
#  ('Anguilla', 'The Valley'),
#  ('Bahrain', 'Manama'),
#  ('Barbados', 'Bridgetown'),
#  ('Botswana', 'Gaborone'),
#  ('Bermuda', 'Hamilton'),
#  ('Belgium', 'Brussels'),
#  ('Bahamas, The', 'Nassau'),
#  ('Bangladesh', 'Dhaka'),
#  ('Belize', 'Belmopan'),
#  ('Bosnia and Herzegovina', 'Sarajevo'),
#  ('Bolivia', 'La Paz'),
#  ('Burma', 'Rangoon'),
#  ('Benin', 'Porto-Novo'),
#  ('Belarus', 'Minsk'),
#  ('Solomon Islands', 'Honiara'),
#  ('Brazil', 'Brasilia'),
#  ('Bhutan', 'Thimphu'),
#  ('Bulgaria', 'Sofia'),
#  ('Brunei', 'Bandar Seri Begawan'),
#  ('Burundi', 'Bujumbura'),
#  ('Canada', 'Ottawa'),
#  ('Cambodia', 'Phnom Penh'),
#  ('Chad', "N'Djamena"),
#  ('Sri Lanka', 'Colombo'),
#  ('Congo, Republic of the', 'Brazzaville'),
#  ('Congo, Democratic Republic of the', 'Kinshasa'),
#  ('China', 'Beijing'),
#  ('Chile', 'Santiago'),
#  ('Cayman Islands', 'George Town'),
#  ('Cameroon', 'Yaounde'),
#  ('Comoros', 'Moroni'),
#  ('Colombia', 'Bogota'),
#  ('Northern Mariana Islands', 'Saipan'),
#  ('Costa Rica', 'San Jose'),
#  ('Central African Republic', 'Bangui'),
#  ('Cuba', 'Havana'),
#  ('Cabo Verde', 'Praia'),
#  ('Cyprus', 'Nicosia'),
#  ('Denmark', 'Copenhagen'),
#  ('Djibouti', 'Djibouti'),
#  ('Dominica', 'Roseau'),
#  ('Dominican Republic', 'Santo Domingo'),
#  ('Ecuador', 'Quito'),
#  ('Egypt', 'Cairo'),
#  ('Ireland', 'Dublin'),
#  ('Equatorial Guinea', 'Malabo'),
#  ('Estonia', 'Tallinn'),
#  ('Eritrea', 'Asmara'),
#  ('El Salvador', 'San Salvador'),
#  ('Ethiopia', 'Addis Ababa'),
#  ('Czech Republic', 'Prague'),
#  ('Finland', 'Helsinki'),
#  ('Fiji', 'Suva'),
#  ('Falkland Islands (Islas Malvinas)', 'Stanley'),
#  ('Micronesia, Federated States of', 'Palikir'),
#  ('Faroe Islands', 'Torshavn'),
#  ('French Polynesia', 'Papeete'),
#  ('France', 'Paris'),
#  ('Gambia, The', 'Banjul'),
#  ('Gabon', 'Libreville'),
#  ('Georgia', 'Tbilisi'),
#  ('Ghana', 'Accra'),
#  ('Grenada', "Saint George'S"),
#  ('Greenland', 'Nuuk'),
#  ('Germany', 'Berlin'),
#  ('Guam', 'Hagatna'),
#  ('Greece', 'Athens'),
#  ('Guatemala', 'Guatemala City'),
#  ('Guinea', 'Conakry'),
#  ('Guyana', 'Georgetown'),
#  ('Haiti', 'Port-Au-Prince'),
#  ('Honduras', 'Tegucigalpa'),
#  ('Croatia', 'Zagreb'),
#  ('Hungary', 'Budapest'),
#  ('Iceland', 'Reykjavik'),
#  ('Indonesia', 'Jakarta'),
#  ('Isle of Man', 'Douglas'),
#  ('India', 'New Delhi'),
#  ('Iran', 'Tehran'),
#  ('Israel', 'Jerusalem'),
#  ('Italy', 'Rome'),
#  ("Cote d'Ivoire", 'Yamoussoukro'),
#  ('Iraq', 'Baghdad'),
#  ('Japan', 'Tokyo'),
#  ('Jamaica', 'Kingston'),
#  ('Jordan', 'Amman'),
#  ('Kenya', 'Nairobi'),
#  ('Kyrgyzstan', 'Bishkek'),
#  ('Korea, North', 'Pyongyang'),
#  ('Kiribati', 'Tarawa'),
#  ('Korea, South', 'Seoul'),
#  ('Kuwait', 'Kuwait'),
#  ('Kazakhstan', 'Astana'),
#  ('Laos', 'Vientiane'),
#  ('Lebanon', 'Beirut'),
#  ('Latvia', 'Riga'),
#  ('Lithuania', 'Vilnius'),
#  ('Liberia', 'Monrovia'),
#  ('Slovakia', 'Bratislava'),
#  ('Liechtenstein', 'Vaduz'),
#  ('Lesotho', 'Maseru'),
#  ('Luxembourg', 'Luxembourg'),
#  ('Libya', 'Tripoli'),
#  ('Madagascar', 'Antananarivo'),
#  ('Moldova', 'Chisinau'),
#  ('Mongolia', 'Ulaanbaatar'),
#  ('Malawi', 'Lilongwe'),
#  ('Montenegro', 'Podgorica'),
#  ('Macedonia', 'Skopje'),
#  ('Mali', 'Bamako'),
#  ('Morocco', 'Rabat'),
#  ('Mauritius', 'Port Louis'),
#  ('Mauritania', 'Nouakchott'),
#  ('Malta', 'Valletta'),
#  ('Oman', 'Muscat'),
#  ('Maldives', 'Male'),
#  ('Mexico', 'Mexico City'),
#  ('Malaysia', 'Kuala Lumpur'),
#  ('Mozambique', 'Maputo'),
#  ('New Caledonia', 'Noumea'),
#  ('Niger', 'Niamey'),
#  ('Vanuatu', 'Port-Vila'),
#  ('Nigeria', 'Abuja'),
#  ('Netherlands', 'Amsterdam'),
#  ('Norway', 'Oslo'),
#  ('Nepal', 'Kathmandu'),
#  ('Suriname', 'Paramaribo'),
#  ('Nicaragua', 'Managua'),
#  ('New Zealand', 'Wellington'),
#  ('South Sudan', 'Juba'),
#  ('Paraguay', 'Asuncion'),
#  ('Peru', 'Lima'),
#  ('Pakistan', 'Islamabad'),
#  ('Poland', 'Warsaw'),
#  ('Panama', 'Panama City'),
#  ('Portugal', 'Lisbon'),
#  ('Papua New Guinea', 'Port Moresby'),
#  ('Palau', 'Melekeok'),
#  ('Guinea-Bissau', 'Bissau'),
#  ('Qatar', 'Doha'),
#  ('Serbia', 'Belgrade'),
#  ('Marshall Islands', 'Majuro'),
#  ('Romania', 'Bucharest'),
#  ('Philippines', 'Manila'),
#  ('Puerto Rico', 'San Juan'),
#  ('Russia', 'Moscow'),
#  ('Rwanda', 'Kigali'),
#  ('Saudi Arabia', 'Riyadh'),
#  ('Saint Pierre and Miquelon', 'Saint-Pierre'),
#  ('Saint Kitts and Nevis', 'Basseterre'),
#  ('Seychelles', 'Victoria'),
#  ('South Africa', 'Pretoria'),
#  ('Senegal', 'Dakar'),
#  ('Saint Helena, Ascension, and Tristan da Cunha', 'Jamestown'),
#  ('Slovenia', 'Ljubljana'),
#  ('Sierra Leone', 'Freetown'),
#  ('Somalia', 'Mogadishu'),
#  ('Spain', 'Madrid'),
#  ('Saint Lucia', 'Castries'),
#  ('Sudan', 'Khartoum'),
#  ('Sweden', 'Stockholm'),
#  ('Syria', 'Damascus'),
#  ('Switzerland', 'Bern'),
#  ('Trinidad and Tobago', 'Port-Of-Spain'),
#  ('Thailand', 'Bangkok'),
#  ('Tajikistan', 'Dushanbe'),
#  ('Turks and Caicos Islands', 'Grand Turk'),
#  ('Togo', 'Lome'),
#  ('Sao Tome and Principe', 'Sao Tome'),
#  ('Tunisia', 'Tunis'),
#  ('Timor-Leste', 'Dili'),
#  ('Turkey', 'Ankara'),
#  ('Tuvalu', 'Funafuti'),
#  ('Turkmenistan', 'Ashgabat'),
#  ('Tanzania', 'Dar Es Salaam'),
#  ('Uganda', 'Kampala'),
#  ('United Kingdom', 'London'),
#  ('Ukraine', 'Kyiv'),
#  ('United States', 'Washington, D.C.'),
#  ('Burkina Faso', 'Ouagadougou'),
#  ('Uruguay', 'Montevideo'),
#  ('Uzbekistan', 'Tashkent'),
#  ('Saint Vincent and the Grenadines', 'Kingstown'),
#  ('Venezuela', 'Caracas'),
#  ('British Virgin Islands', 'Road Town'),
#  ('Vietnam', 'Hanoi'),
#  ('Virgin Islands', 'Charlotte Amalie'),
#  ('Namibia', 'Windhoek'),
#  ('Wallis and Futuna', 'Mata-Utu'),
#  ('Samoa', 'Apia'),
#  ('Swaziland', 'Mbabane'),
#  ('Yemen', 'Sanaa'),
#  ('Zambia', 'Lusaka'),
#  ('Zimbabwe', 'Harare')]

# %% [markdown]
# As we mentioned earlier, an inner join will not include any rows where there is not a mutual match from both tables. This means there could be information we are not seeing in our query where rows don't match.
#
# We can use some SQL queries to explore this

# %%
# %%sql
# SELECT COUNT(DISTINCT(name)) FROM facts;
# Out:
#  * sqlite:///factbook-join.db
#    sqlite:///factbook.db
# Done.
# [(261,)]

# %%
# %%sql
# SELECT COUNT(DISTINCT(facts_id)) FROM cities;
# Out:
#  * sqlite:///factbook-join.db
#    sqlite:///factbook.db
# Done.
# [(210,)]

# %% [markdown]
# By running these two queries, we can see that there are some countries in the `facts` table that don't have corresponding `cities` in the cities table, which indicates we may have some incomplete data.
#
# ### Left joins

# %% [markdown]
# A left join includes all the rows that an inner join will select, plus any rows from the first (or left) table that don't have a match in the second table.
#
# Let's look at an example by replacing INNER JOIN with LEFT JOIN from the first query we wrote,

# %%
# %%sql
# SELECT * FROM facts
# LEFT JOIN cities ON cities.facts_id = facts.id
# Out:
#  * sqlite:///factbook-join.db
#    sqlite:///factbook.db
# Done.
# [(1, 'af', 'Afghanistan', 652230, 652230, 0, 32564342, 2.32, 38.57, 13.89, 1.51, 6, 'Kabul', 3097000, 1, '1'),
#  (2, 'al', 'Albania', 28748, 27398, 1350, 3029278, 0.3, 12.92, 6.58, 3.3, 10, 'Tirana', 419000, 1, '2'),
#  (3, 'ag', 'Algeria', 2381741, 2381741, 0, 39542166, 1.84, 23.67, 4.31, 0.92, 7, 'Algiers', 2916000, 1, '3'),
#  (3, 'ag', 'Algeria', 2381741, 2381741, 0, 39542166, 1.84, 23.67, 4.31, 0.92, 8, 'Oran', 783000, 0, '3'),
#  (4, 'an', 'Andorra', 468, 468, 0, 85580, 0.12, 8.13, 6.96, 0.0, 12, 'Andorra La Vella', 23000, 1, '4'),
#  (5, 'ao', 'Angola', 1246700, 1246700, 0, 19625353, 2.78, 38.78, 11.49, 0.46, 13, 'Luanda', 5068000, 1, '5'),
#  (5, 'ao', 'Angola', 1246700, 1246700, 0, 19625353, 2.78, 38.78, 11.49, 0.46, 14, 'Huambo', 1098000, 0, '5'),
#  (6, 'ac', 'Antigua and Barbuda', 442, 442, 0, 92436, 1.24, 15.85, 5.69, 2.21, 2, "Saint John'S", 27000, 1, '6'),
#  (7, 'ar', 'Argentina', 2780400, 2736690, 43710, 43431886, 0.93, 16.64, 7.33, 0.0, 16, 'Buenos Aires', 13528000, 1, '7'),
#  (7, 'ar', 'Argentina', 2780400, 2736690, 43710, 43431886, 0.93, 16.64, 7.33, 0.0, 17, 'Cordoba', 1556000, 0, '7'),
#  (143, 'rs', 'Russia', 17098242, 16377742, 720500, 142423773, 0.04, 11.6, 13.69, 1.69, 298, 'Novosibirsk', 1478000, 0, '143'),
#  (143, 'rs', 'Russia', 17098242, 16377742, 720500, 142423773, 0.04, 11.6, 13.69, 1.69, 299, 'Yekaterinburg', 1355000, 0, '143'),
#  (143, 'rs', 'Russia', 17098242, 16377742, 720500, 142423773, 0.04, 11.6, 13.69, 1.69, 300, 'Nizhniy Novgorod', 1245000, 0, '143'),
#  (143, 'rs', 'Russia', 17098242, 16377742, 720500, 142423773, 0.04, 11.6, 13.69, 1.69, 301, 'Samara', 1166000, 0, '143'),
#  (144, 'rw', 'Rwanda', 26338, 24668, 1670, 12661733, 2.56, 33.75, 8.96, 0.85, 302, 'Kigali', 1004000, 1, '144'),
#  (145, 'sc', 'Saint Kitts and Nevis', 261, 261, 0, 51936, 0.76, 13.5, 7.09, 1.21, 309, 'Basseterre', 12000, 1, '145'),
#  (146, 'st', 'Saint Lucia', 616, 606, 10, 163922, 0.34, 13.7, 7.42, 2.93, 326, 'Castries', 21000, 1, '146'),
#  (147, 'vc', 'Saint Vincent and the Grenadines', 389, 389, 0, 102627, 0.28, 13.57, 7.18, 9.17, 376, 'Kingstown', 31000, 1, '147'),
#  (148, 'ws', 'Samoa', 2831, 2821, 10, 197773, 0.58, 20.87, 5.32, 9.78, 392, 'Apia', 37000, 1, '148'),
#  (149, 'sm', 'San Marino', 61, 61, 0, 33020, 0.82, 8.63, 8.45, 8.03, None, None, None, None, None),
#  (150, 'tp', 'Sao Tome and Principe', 964, 964, 0, 194006, 1.84, 34.23, 7.24, 8.63, 342, 'Sao Tome', 64000, 1, '150'),
#  (151, 'sa', 'Saudi Arabia', 2149690, 2149690, 0, 27752316, 1.46, 18.51, 3.33, 0.55, 303, 'Riyadh', 5451000, 1, '151'),
#  (151, 'sa', 'Saudi Arabia', 2149690, 2149690, 0, 27752316, 1.46, 18.51, 3.33, 0.55, 304, 'Jeddah', 3578000, 0, '151'),
#  (151, 'sa', 'Saudi Arabia', 2149690, 2149690, 0, 27752316, 1.46, 18.51, 3.33, 0.55, 305, 'Mecca', 1591000, 0, '151'),
#  (151, 'sa', 'Saudi Arabia', 2149690, 2149690, 0, 27752316, 1.46, 18.51, 3.33, 0.55, 306, 'Medina', 1142000, 0, '151'),
#  (151, 'sa', 'Saudi Arabia', 2149690, 2149690, 0, 27752316, 1.46, 18.51, 3.33, 0.55, 307, 'Ad Dammam', 941000, 0, '151'),
#  (152, 'sg', 'Senegal', 196722, 192530, 4192, 13975834, 2.45, 34.52, 8.46, 1.59, 318, 'Dakar', 3035000, 1, '152'),
#  (153, 'ri', 'Serbia', 77474, 77474, 0, 7176794, 0.46, 9.08, 13.66, 0.0, 288, 'Belgrade', 1135000, 1, '153'),
#  (154, 'se', 'Seychelles', 455, 455, 0, 92430, 0.83, 14.19, 6.89, 1.0, 310, 'Victoria', 27000, 1, '154'),
#  (155, 'sl', 'Sierra Leone', 71740, 71620, 120, 5879098, 2.35, 37.03, 10.81, 2.77, 321, 'Freetown', 941000, 1, '155'),
#  (179, 'tu', 'Turkey', 783562, 769632, 13930, 79414269, 1.26, 16.33, 5.88, 2.16, 348, 'Bursa', 1713000, 0, '179'),
#  (179, 'tu', 'Turkey', 783562, 769632, 13930, 79414269, 1.26, 16.33, 5.88, 2.16, 349, 'Adana', 1468000, 0, '179'),
#  (179, 'tu', 'Turkey', 783562, 769632, 13930, 79414269, 1.26, 16.33, 5.88, 2.16, 350, 'Gaziantep', 1198000, 0, '179'),
#  (180, 'tx', 'Turkmenistan', 488100, 469930, 18170, 5231422, 1.14, 19.4, 6.13, 1.84, 352, 'Ashgabat', 683000, 1, '180'),
#  (181, 'tv', 'Tuvalu', 26, 26, 0, 10869, 0.82, 23.74, 8.74, 6.81, 351, 'Funafuti', 5000, 1, '181'),
#  (182, 'ug', 'Uganda', 241038, 197100, 43938, 37101745, 3.24, 43.79, 10.69, 0.74, 354, 'Kampala', 1659000, 1, '182'),
#  (183, 'up', 'Ukraine', 603550, 579330, 24220, 44429471, 0.6, 10.72, 14.46, 2.25, 361, 'Kyiv', 2829000, 1, '183'),
#  (183, 'up', 'Ukraine', 603550, 579330, 24220, 44429471, 0.6, 10.72, 14.46, 2.25, 362, 'Kharkiv', 1451000, 0, '183'),
#  (183, 'up', 'Ukraine', 603550, 579330, 24220, 44429471, 0.6, 10.72, 14.46, 2.25, 363, 'Dnipropetrovsk', 994000, 0, '183'),
#  (183, 'up', 'Ukraine', 603550, 579330, 24220, 44429471, 0.6, 10.72, 14.46, 2.25, 364, 'Odesa', 101000, 0, '183'),
#  (183, 'up', 'Ukraine', 603550, 579330, 24220, 44429471, 0.6, 10.72, 14.46, 2.25, 365, 'Donetsk', 959000, 0, '183'),
#  (183, 'up', 'Ukraine', 603550, 579330, 24220, 44429471, 0.6, 10.72, 14.46, 2.25, 366, 'Zaporizhzhya', 771000, 0, '183'),
#  (184, 'ae', 'United Arab Emirates', 83600, 83600, 0, 5779760, 2.58, 15.43, 1.97, 12.36, 3, 'Abu Dhabi', 942000, 1, '184'),
#  (184, 'ae', 'United Arab Emirates', 83600, 83600, 0, 5779760, 2.58, 15.43, 1.97, 12.36, 4, 'Dubai', 1978000, 0, '184'),
#  (184, 'ae', 'United Arab Emirates', 83600, 83600, 0, 5779760, 2.58, 15.43, 1.97, 12.36, 5, 'Sharjah', 983000, 0, '184'),
#  (185, 'uk', 'United Kingdom', 243610, 241930, 1680, 64088222, 0.54, 12.17, 9.35, 2.54, 355, 'London', 9005000, 1, '185'),
#  (185, 'uk', 'United Kingdom', 243610, 241930, 1680, 64088222, 0.54, 12.17, 9.35, 2.54, 356, 'Birmingham', 2272000, 0, '185'),
#  (185, 'uk', 'United Kingdom', 243610, 241930, 1680, 64088222, 0.54, 12.17, 9.35, 2.54, 357, 'Manchester', 2213000, 0, '185'),
#  (185, 'uk', 'United Kingdom', 243610, 241930, 1680, 64088222, 0.54, 12.17, 9.35, 2.54, 358, 'West Yorkshire', 1625000, 0, '185'),
#  (192, 'vm', 'Vietnam', 331210, 310070, 21140, 94348835, 0.97, 15.96, 5.93, 0.3, 386, 'Haiphong', 925000, 0, '192'),
#  (192, 'vm', 'Vietnam', 331210, 310070, 21140, 94348835, 0.97, 15.96, 5.93, 0.3, 387, 'Da Nang', 834000, 0, '192'),
#  (193, 'ym', 'Yemen', 527968, 527968, 0, 26737317, 2.47, 29.98, 6.28, 1.0, 394, 'Sanaa', 2419000, 1, '193'),
#  (193, 'ym', 'Yemen', 527968, 527968, 0, 26737317, 2.47, 29.98, 6.28, 1.0, 395, 'Aden', 784000, 0, '193'),
#  (194, 'za', 'Zambia', 752618, 743398, 9220, 15066266, 2.88, 42.13, 12.67, 0.68, 396, 'Lusaka', 1802000, 1, '194'),
#  (195, 'zi', 'Zimbabwe', 390757, 386847, 3910, 14229541, 2.21, 32.26, 10.13, 0.0, 397, 'Harare', 1542000, 1, '195'),
#  (196, 'tw', 'Taiwan', 35980, 32260, 3720, 23415126, 0.23, 8.47, 7.11, 0.89, None, None, None, None, None),
#  (197, 'ee', 'European Union', 4324782, None, None, 513949445, 0.25, 10.2, 10.2, 2.5, None, None, None, None, None),
#  (198, 'at', 'Ashmore and Cartier Islands', 5, 5, 0, None, None, None, None, None, None, None, None, None, None),
#  (199, 'kt', 'Christmas Island', 135, 135, 0, 1530, 1.11, None, None, None, None, None, None, None, None),
#  (200, 'ck', 'Cocos (Keeling) Islands', 14, 14, 0, 596, 0.0, None, None, None, None, None, None, None, None),
#  (201, 'cr', 'Coral Sea Islands', 3, 3, 0, None, None, None, None, None, None, None, None, None, None),
#  (202, 'hm', 'Heard Island and McDonald Islands', 412, 412, 0, None, None, None, None, None, None, None, None, None, None),
#  (203, 'nf', 'Norfolk Island', 36, 36, 0, 2210, 0.01, None, None, None, None, None, None, None, None),
#  (204, 'hk', 'Hong Kong', 1108, 1073, 35, 7141106, 0.38, 9.23, 7.07, 1.68, None, None, None, None, None),
#  (205, 'mc', 'Macau', 28, 28, 0, 592731, 0.8, 8.88, 4.22, 3.37, None, None, None, None, None),
#  (206, 'fo', 'Faroe Islands', 1393, 1393, 0, 50196, 0.51, 13.77, 8.71, 0.0, 124, 'Torshavn', 20000, 1, '206'),
#  (207, 'gl', 'Greenland', 2166086, 2166086, None, 57733, 0.0, 14.48, 8.49, 5.98, 138, 'Nuuk', 16000, 1, '207'),
#  (208, 'ip', 'Clipperton Island', 6, 6, 0, None, None, None, None, None, None, None, None, None, None),
#  (209, 'fp', 'French Polynesia', 4167, 3827, 340, 282703, 0.94, 15.22, 5.02, 0.84, 125, 'Papeete', 137000, 1, '209'),
#  (210, 'fs', 'French Southern and Antarctic Lands', None, None, None, None, None, None, None, None, None, None, None, None, None),
#  (211, 'nc', 'New Caledonia', 18575, 18275, 300, 271615, 1.38, 15.33, 5.52, 4.01, 251, 'Noumea', 157000, 1, '211'),
#  (212, 'tb', 'Saint Barthelemy', None, None, None, 7237, None, None, None, None, None, None, None, None, None),
#  (213, 'rn', 'Saint Martin', 54, 54, None, 31754, None, None, None, None, None, None, None, None, None),
#  (214, 'sb', 'Saint Pierre and Miquelon', 242, 242, 0, 5657, 1.08, 7.42, 9.72, 8.49, 308, 'Saint-Pierre', 5000, 1, '214'),
#  (215, 'wf', 'Wallis and Futuna', 142, 142, 0, 15613, 0.33, 13.45, 5.06, 5.06, 390, 'Mata-Utu', 1000, 1, '215'),
#  (216, 'aa', 'Aruba', 180, 180, 0, 112162, 1.33, 12.56, 8.18, 8.92, 1, 'Oranjestad', 37000, 1, '216'),
#  (217, 'cc', 'Curacao', 444, 444, 0, 148406, 0.43, 13.8, 8.2, 1.4, None, None, None, None, None),
#  (218, 'sk', 'Sint Maarten', 34, 34, 0, 39689, 1.51, 13.0, 4.51, 6.63, None, None, None, None, None),
#  (219, 'cw', 'Cook Islands', 236, 236, 0, 9838, 2.95, 14.33, 8.03, None, None, None, None, None, None),
#  (220, 'ne', 'Niue', 260, 260, 0, 1190, 0.03, None, None, None, None, None, None, None, None),
#  (221, 'tl', 'Tokelau', 12, 12, 0, 1337, 0.01, None, None, None, None, None, None, None, None),
#  (222, 'bv', 'Bouvet Island', 49, 49, 0, None, None, None, None, None, None, None, None, None, None),
#  (223, 'jn', 'Jan Mayen', 377, 377, 0, None, None, None, None, None, None, None, None, None, None),
#  (224, 'sv', 'Svalbard', 62045, 62045, 0, 1872, 0.03, None, None, None, None, None, None, None, None),
#  (225, 'ax', 'Akrotiri', 123, None, None, 15700, None, None, None, None, None, None, None, None, None),
#  (226, 'av', 'Anguilla', 91, 91, 0, 16418, 2.03, 12.67, 4.57, 12.18, 29, 'The Valley', 2000, 1, '226'),
#  (227, 'bd', 'Bermuda', 54, 54, 0, 70196, 0.5, 11.33, 8.23, 1.88, 33, 'Hamilton', 11000, 1, '227'),
#  (228, 'io', 'British Indian Ocean Territory', 54400, 60, 54340, None, None, None, None, None, None, None, None, None, None),
#  (229, 'vi', 'British Virgin Islands', 151, 151, 0, 33454, 2.32, 10.91, 4.99, 17.28, 383, 'Road Town', 10000, 1, '229'),
#  (230, 'cj', 'Cayman Islands', 264, 264, 0, 56092, 2.1, 12.11, 5.53, 14.4, 89, 'George Town', 28000, 1, '230'),
#  (231, 'dx', 'Dhekelia', 130, None, None, 15700, None, None, None, None, None, None, None, None, None),
#  (232, 'fk', 'Falkland Islands (Islas Malvinas)', 12173, 12173, 0, 3361, 0.01, 10.9, 4.9, None, 122, 'Stanley', 2000, 1, '232'),
#  (233, 'gi', 'Gibraltar', 6, 6, 0, 29258, 0.24, 14.08, 8.37, 3.28, None, None, None, None, None),
#  (234, 'gk', 'Guernsey', 78, 78, 0, 66080, 0.34, 9.84, 8.78, 2.32, None, None, None, None, None),
#  (235, 'je', 'Jersey', 116, 116, 0, 97294, 0.8, 11.91, 7.68, 3.76, None, None, None, None, None),
#  (236, 'im', 'Isle of Man', 572, 572, 0, 87545, 0.76, 11.1, 10.06, 6.56, 160, 'Douglas', 27000, 1, '236'),
#  (237, 'mh', 'Montserrat', 102, 102, 0, 5241, 0.5, 11.26, 6.3, 0.0, None, None, None, None, None),
#  (238, 'pc', 'Pitcairn Islands', 47, 47, 0, 48, 0.0, None, None, None, None, None, None, None, None),
#  (239, 'sh', 'Saint Helena, Ascension, and Tristan da Cunha', 308, 122, 0, 7795, 0.24, 9.88, 7.44, 0.0, 319, 'Jamestown', 1000, 1, '239'),
#  (240, 'sx', 'South Georgia and South Sandwich Islands', 3903, 3903, 0, None, None, None, None, None, None, None, None, None, None),
#  (241, 'tk', 'Turks and Caicos Islands', 948, 948, 0, 50280, 2.3, 16.13, 3.1, 9.94, 339, 'Grand Turk', 7000, 1, '241'),
#  (242, 'aq', 'American Samoa', 199, 199, 0, 54343, 0.3, 22.89, 4.75, 21.13, 15, 'Pago Pago', 64000, 1, '242'),
#  (243, 'gq', 'Guam', 544, 544, 0, 161785, 0.54, 16.82, 5.12, 6.34, 143, 'Hagatna', 169000, 1, '243'),
#  (244, 'bq', 'Navassa Island', 5, 5, 0, None, None, None, None, None, None, None, None, None, None),
#  (245, 'cq', 'Northern Mariana Islands', 464, 464, 0, 52344, 2.18, 18.32, 3.71, 7.16, 99, 'Saipan', 56000, 1, '245'),
#  (246, 'rq', 'Puerto Rico', 13791, 8870, 4921, 3598357, 0.6, 10.86, 8.67, 8.15, 295, 'San Juan', 2475000, 1, '246'),
#  (247, 'vq', 'Virgin Islands', 1910, 346, 1564, 103574, 0.59, 10.31, 8.54, 7.67, 388, 'Charlotte Amalie', 60000, 1, '247'),
#  (248, 'wq', 'Wake Island', 6, 6, 0, None, None, None, None, None, None, None, None, None, None),
#  (249, 'um', 'United States Pacific Island Wildlife Refuges', None, None, None, None, None, None, None, None, None, None, None, None, None),
#  (250, 'ay', 'Antarctica', None, 280000, None, 0, None, None, None, None, None, None, None, None, None),
#  (251, 'gz', 'Gaza Strip', 360, 360, 0, 1869055, 2.81, 31.11, 3.04, 0.0, None, None, None, None, None),
#  (252, 'pf', 'Paracel Islands', 7, 7, 0, None, None, None, None, None, None, None, None, None, None),
#  (253, 'pg', 'Spratly Islands', 5, 5, 0, None, None, None, None, None, None, None, None, None, None),
#  (254, 'we', 'West Bank', 5860, 5640, 220, 2785366, 1.95, 22.99, 3.5, 0.0, None, None, None, None, None),
#  (255, 'wi', 'Western Sahara', 266000, 266000, 0, 570866, 2.82, 30.24, 8.34, None, 391, 'Laayoune', 237000, 0, '255'),
#  (256, 'xq', 'Arctic Ocean', None, None, None, None, None, None, None, None, None, None, None, None, None),
#  (257, 'zh', 'Atlantic Ocean', None, None, None, None, None, None, None, None, None, None, None, None, None),
#  (258, 'xo', 'Indian Ocean', None, None, None, None, None, None, None, None, None, None, None, None, None),
#  (259, 'zn', 'Pacific Ocean', None, None, None, None, None, None, None, None, None, None, None, None, None),
#  (260, 'oo', 'Southern Ocean', None, None, None, None, None, None, None, None, None, None, None, None, None),
#  (261, 'xx', 'World', None, None, None, 7256490011, 1.08, 18.6, 7.8, None, None, None, None, None, None)]

# %% [markdown]
# Here we can see that for the rows where `facts.id` doesn't match any values in `cities.facts_id (237, 238, 240, and 244)`, the rows are still included in the results. When this happens, all of the columns from the `cities` table are populated with `null` values.
#
# We can use these null values to filter our results to just the countries that don't exist in `cities` with a `WHERE` clause. When making a comparison to null in SQL, we use the `IS` keyword, rather than the = sign. If we want to select rows where a column is null we can write:
#
# WHERE column_name IS NULL

# %% [markdown]
# If we want to select rows where a column name isn't null, we use:
#
# WHERE column_name IS NOT NULL
#
# Let's use a left join to explore the countries that don't exist in the cities table.
#
# Write a query that returns the countries that don't exist in cities:
# - Your query should return two columns:
#     - The country names, with the alias country.
#     - The country population.
# - Use a LEFT JOIN to join cities to facts.
# - Include only the countries from facts that don't have a corresponding value in cities.

# %%
# %%sql
# SELECT f.name country, f.population
# FROM facts f
# LEFT JOIN cities c ON c.facts_id = f.id
# WHERE c.name IS NULL;
# Out:
#  * sqlite:///factbook-join.db
#    sqlite:///factbook.db
# Done.
# [('Kosovo', 1870981),
#  ('Monaco', 30535),
#  ('Nauru', 9540),
#  ('San Marino', 33020),
#  ('Singapore', 5674472),
#  ('Holy See (Vatican City)', 842),
#  ('Taiwan', 23415126),
#  ('European Union', 513949445),
#  ('Ashmore and Cartier Islands', None),
#  ('Christmas Island', 1530),
#  ('Cocos (Keeling) Islands', 596),
#  ('Coral Sea Islands', None),
#  ('Heard Island and McDonald Islands', None),
#  ('Norfolk Island', 2210),
#  ('Hong Kong', 7141106),
#  ('Macau', 592731),
#  ('Clipperton Island', None),
#  ('French Southern and Antarctic Lands', None),
#  ('Saint Barthelemy', 7237),
#  ('Saint Martin', 31754),
#  ('Curacao', 148406),
#  ('Sint Maarten', 39689),
#  ('Cook Islands', 9838),
#  ('Niue', 1190),
#  ('Tokelau', 1337),
#  ('Bouvet Island', None),
#  ('Jan Mayen', None),
#  ('Svalbard', 1872),
#  ('Akrotiri', 15700),
#  ('British Indian Ocean Territory', None),
#  ('Dhekelia', 15700),
#  ('Gibraltar', 29258),
#  ('Guernsey', 66080),
#  ('Jersey', 97294),
#  ('Montserrat', 5241),
#  ('Pitcairn Islands', 48),
#  ('South Georgia and South Sandwich Islands', None),
#  ('Navassa Island', None),
#  ('Wake Island', None),
#  ('United States Pacific Island Wildlife Refuges', None),
#  ('Antarctica', 0),
#  ('Gaza Strip', 1869055),
#  ('Paracel Islands', None),
#  ('Spratly Islands', None),
#  ('West Bank', 2785366),
#  ('Arctic Ocean', None),
#  ('Atlantic Ocean', None),
#  ('Indian Ocean', None),
#  ('Pacific Ocean', None),
#  ('Southern Ocean', None),
#  ('World', 7256490011)]

# %% [markdown]
# Looking through the results of the query we wrote in the previous screen, we can see a number of different reasons that countries don't have corresponding values in cities:
#
# - Countries with small populations and/or no major urban areas (which are defined as having populations of over 750,000), eg San Marino, Kosovo, and Nauru.
# - City-states, such as Monaco and Singapore.
# - Territories that are not themselves countries, such as Hong Kong, Gibraltar, and the Cook Islands.
# - Regions & Oceans that aren't countries, such as the European Union and the Pacific Ocean.
# - Genuine cases of missing data, such as Taiwan.
#
# It's important whenever you use inner joins to be mindful that you might be excluding important data, especially if you are joining based on columns that aren't linked in the database schema.
#
# ### Right Joins
#
# There are two less-common join types SQLite does not support that you should be aware of. The first is a `right join`. A right join, as the name indicates, is exactly the opposite of a left join. While the left join includes all rows in the table before the JOIN clause, the right join includes all rows in the new table in the JOIN clause.
#
# The following two queries, one using a left join and one using a right join, produce identical results.

# %%
# %%sql
# SELECT f.name country, c.name city
# FROM facts f
# LEFT JOIN cities c ON c.facts_id = f.id
# LIMIT 5;
# Out:
#  * sqlite:///factbook-join.db
#    sqlite:///factbook.db
# Done.
# [('Afghanistan', 'Kabul'),
#  ('Albania', 'Tirana'),
#  ('Algeria', 'Algiers'),
#  ('Algeria', 'Oran'),
#  ('Andorra', 'Andorra La Vella')]

# %%
# %%sql
# SELECT COUNT(DISTINCT(facts_id)) FROM cities;
# SELECT f.name country, c.name city
# FROM cities c
# RIGHT JOIN facts f ON f.id = c.facts_id
# LIMIT 5;
# Out:
#  * sqlite:///factbook-join.db
#    sqlite:///factbook.db
# Done.
# (sqlite3.OperationalError) RIGHT and FULL OUTER JOINs are not currently supported
# [SQL: SELECT f.name country, c.name city
# FROM cities c
# RIGHT JOIN facts f ON f.id = c.facts_id
# LIMIT 5;]
# (Background on this error at: http://sqlalche.me/e/13/e3q8)

# %% [markdown]
# The main reason a `right join` would be used is when you are joining more than two tables. In these cases, using a right join is preferable because it can avoid restructuring your whole query to join one table. Outside of this, right joins are used reasonably rarely, so for simple joins it's better to use a left join than a right as it will be easier for your query to be read and understood by others.
#
# ### Full Outer Joins
#
# The other join type not supported by SQLite is a `full outer join`. A full outer join will include all rows from the tables on both sides of the join.
#
# Like right joins, full outer joins are reasonably uncommon, and similar results can be achieved using a union clause (which we will teach in the next mission). The standard SQL syntax for a full outer join is:

# %%
# %%sql
# SELECT f.name country, c.name city
# FROM cities c
# FULL OUTER JOIN facts f ON f.id = c.facts_id
# LIMIT 5;
# Out:
#  * sqlite:///factbook-join.db
#    sqlite:///factbook.db
# (sqlite3.OperationalError) RIGHT and FULL OUTER JOINs are not currently supported
# [SQL: SELECT f.name country, c.name city
# FROM cities c
# FULL OUTER JOIN facts f ON f.id = c.facts_id
# LIMIT 5;]
# (Background on this error at: http://sqlalche.me/e/13/e3q8)

# %% [markdown]
# When joining `cities` and `facts` with a full outer join, the result will be the same as our left and right joins above, because there are no values in `cities.facts_id` that don't exist in `facts.id`.

# %% [markdown]
# ### Finding the Most Populous Capital Cities
#
# Previously, we've used column names when specifying order for our query results, like so:

# %%
# %%sql
# SELECT name, migration_rate FROM FACTS
# ORDER BY migration_rate desc;
# Out:
#  * sqlite:///factbook-join.db
#    sqlite:///factbook.db
# Done.
# [('Qatar', 22.39),
#  ('American Samoa', 21.13),
#  ('Micronesia, Federated States of', 20.93),
#  ('Syria', 19.79),
#  ('Tonga', 17.84),
#  ('British Virgin Islands', 17.28),
#  ('Luxembourg', 17.16),
#  ('Cayman Islands', 14.4),
#  ('Singapore', 14.05),
#  ('Nauru', 13.63),
#  ('Jordan', 13.24),
#  ('Bahrain', 13.09),
#  ('Maldives', 12.68),
#  ('United Arab Emirates', 12.36),
#  ('Anguilla', 12.18),
#  ('South Sudan', 11.47),
#  ('Turks and Caicos Islands', 9.94),
#  ('Samoa', 9.78),
#  ('Moldova', 9.67),
#  ('Cyprus', 9.48),
#  ('Saint Vincent and the Grenadines', 9.17),
#  ('Aruba', 8.92),
#  ('Sao Tome and Principe', 8.63),
#  ('Somalia', 8.49),
#  ('Saint Pierre and Miquelon', 8.49),
#  ('Spain', 8.31),
#  ('El Salvador', 8.28),
#  ('Puerto Rico', 8.15),
#  ('Guyana', 8.06),
#  ('San Marino', 8.03),
#  ('Libya', 7.8),
#  ('Virgin Islands', 7.67),
#  ('Lesotho', 7.36),
#  ('Norway', 7.25),
#  ('Northern Mariana Islands', 7.16),
#  ('Tuvalu', 6.81),
#  ('Fiji', 6.75),
#  ('Sint Maarten', 6.63),
#  ('Isle of Man', 6.56),
#  ('Guam', 6.34),
#  ('Lithuania', 6.27),
#  ('Latvia', 6.26),
#  ('Trinidad and Tobago', 6.25),
#  ('Djibouti', 6.06),
#  ('Greenland', 5.98),
#  ('Congo, Republic of the', 5.9),
#  ('Belgium', 5.87),
#  ('Armenia', 5.8),
#  ('Canada', 5.66),
#  ('Australia', 5.65),
#  ('Austria', 5.56),
#  ('Sweden', 5.42),
#  ('Dominica', 5.38),
#  ('Kyrgyzstan', 5.22),
#  ('Liechtenstein', 5.08),
#  ('Wallis and Futuna', 5.06),
#  ('Marshall Islands', 4.83),
#  ('Switzerland', 4.74),
#  ('Jamaica', 4.66),
#  ('Botswana', 4.56),
#  ('Iceland', 4.43),
#  ('Sudan', 4.29),
#  ('Italy', 4.1),
#  ('Ireland', 4.09),
#  ('New Caledonia', 4.01),
#  ('Nepal', 3.86),
#  ('Timor-Leste', 3.86),
#  ('United States', 3.86),
#  ('Monaco', 3.83),
#  ('Jersey', 3.76),
#  ('Cuba', 3.66),
#  ('Estonia', 3.6),
#  ('Chad', 3.45),
#  ('Macau', 3.37),
#  ('Morocco', 3.36),
#  ('Albania', 3.3),
#  ('Gibraltar', 3.28),
#  ('Grenada', 3.13),
#  ('Finland', 3.1),
#  ('Nicaragua', 3.0),
#  ('Saint Lucia', 2.93),
#  ('Kiribati', 2.87),
#  ('Sierra Leone', 2.77),
#  ('Haiti', 2.76),
#  ('Georgia', 2.7),
#  ('Portugal', 2.67),
#  ('United Kingdom', 2.54),
#  ('Comoros', 2.53),
#  ('Peru', 2.53),
#  ('European Union', 2.5),
#  ('Brunei', 2.43),
#  ('South Africa', 2.42),
#  ('Uzbekistan', 2.37),
#  ('Czech Republic', 2.33),
#  ('Greece', 2.32),
#  ('Guernsey', 2.32),
#  ('Mali', 2.26),
#  ('Ukraine', 2.25),
#  ('Israel', 2.24),
#  ('Antigua and Barbuda', 2.21),
#  ('New Zealand', 2.21),
#  ('Denmark', 2.2),
#  ('Turkey', 2.16),
#  ('Gambia, The', 2.12),
#  ('Philippines', 2.09),
#  ('Gabon', 2.03),
#  ('Ghana', 2.02),
#  ('Malta', 1.98),
#  ('Mozambique', 1.98),
#  ('Guatemala', 1.97),
#  ('Netherlands', 1.95),
#  ('Dominican Republic', 1.91),
#  ('Bermuda', 1.88),
#  ('Turkmenistan', 1.84),
#  ('Solomon Islands', 1.75),
#  ('Tunisia', 1.73),
#  ('Russia', 1.69),
#  ('Mexico', 1.68),
#  ('Hong Kong', 1.68),
#  ('Iraq', 1.62),
#  ('Senegal', 1.59),
#  ('Kuwait', 1.58),
#  ('Pakistan', 1.54),
#  ('Afghanistan', 1.51),
#  ('Vanuatu', 1.47),
#  ('Curacao', 1.4),
#  ('Croatia', 1.39),
#  ('Sri Lanka', 1.35),
#  ('Hungary', 1.33),
#  ('Germany', 1.24),
#  ('Saint Kitts and Nevis', 1.21),
#  ('Honduras', 1.16),
#  ('Indonesia', 1.16),
#  ('Tajikistan', 1.15),
#  ('Lebanon', 1.1),
#  ('France', 1.09),
#  ('Laos', 1.09),
#  ('Seychelles', 1.0),
#  ('Yemen', 1.0),
#  ('Algeria', 0.92),
#  ('Uruguay', 0.9),
#  ('Taiwan', 0.89),
#  ('Rwanda', 0.85),
#  ('Mongolia', 0.84),
#  ('French Polynesia', 0.84),
#  ('Costa Rica', 0.83),
#  ('Mauritania', 0.83),
#  ('Uganda', 0.74),
#  ('Palau', 0.71),
#  ('Belarus', 0.7),
#  ('Zambia', 0.68),
#  ('Colombia', 0.64),
#  ('Cabo Verde', 0.63),
#  ('Bolivia', 0.62),
#  ('Niger', 0.56),
#  ('Suriname', 0.56),
#  ('Saudi Arabia', 0.55),
#  ('Tanzania', 0.54),
#  ('Macedonia', 0.48),
#  ('Angola', 0.46),
#  ('Bangladesh', 0.46),
#  ('Poland', 0.46),
#  ('China', 0.44),
#  ('Oman', 0.43),
#  ('Kazakhstan', 0.41),
#  ('Bosnia and Herzegovina', 0.38),
#  ('Slovenia', 0.37),
#  ('Chile', 0.34),
#  ('Malaysia', 0.33),
#  ('Cambodia', 0.32),
#  ('Barbados', 0.3),
#  ('Vietnam', 0.3),
#  ('Bulgaria', 0.29),
#  ('Burma', 0.28),
#  ('Panama', 0.28),
#  ('Congo, Democratic Republic of the', 0.27),
#  ('Romania', 0.24),
#  ('Ethiopia', 0.22),
#  ('Kenya', 0.22),
#  ('Nigeria', 0.22),
#  ('Egypt', 0.19),
#  ('Cameroon', 0.15),
#  ('Brazil', 0.14),
#  ('Iran', 0.07),
#  ('Paraguay', 0.07),
#  ('India', 0.04),
#  ('Korea, North', 0.04),
#  ('Slovakia', 0.04),
#  ('Andorra', 0.0),
#  ('Argentina', 0.0),
#  ('Azerbaijan', 0.0),
#  ('Bahamas, The', 0.0),
#  ('Belize', 0.0),
#  ('Benin', 0.0),
#  ('Bhutan', 0.0),
#  ('Burkina Faso', 0.0),
#  ('Burundi', 0.0),
#  ('Central African Republic', 0.0),
#  ("Cote d'Ivoire", 0.0),
#  ('Ecuador', 0.0),
#  ('Equatorial Guinea', 0.0),
#  ('Eritrea', 0.0),
#  ('Guinea', 0.0),
#  ('Guinea-Bissau', 0.0),
#  ('Japan', 0.0),
#  ('Korea, South', 0.0),
#  ('Liberia', 0.0),
#  ('Madagascar', 0.0),
#  ('Malawi', 0.0),
#  ('Mauritius', 0.0),
#  ('Namibia', 0.0),
#  ('Papua New Guinea', 0.0),
#  ('Serbia', 0.0),
#  ('Swaziland', 0.0),
#  ('Thailand', 0.0),
#  ('Togo', 0.0),
#  ('Venezuela', 0.0),
#  ('Zimbabwe', 0.0),
#  ('Faroe Islands', 0.0),
#  ('Montserrat', 0.0),
#  ('Saint Helena, Ascension, and Tristan da Cunha', 0.0),
#  ('Gaza Strip', 0.0),
#  ('West Bank', 0.0),
#  ('Kosovo', None),
#  ('Montenegro', None),
#  ('Holy See (Vatican City)', None),
#  ('Ashmore and Cartier Islands', None),
#  ('Christmas Island', None),
#  ('Cocos (Keeling) Islands', None),
#  ('Coral Sea Islands', None),
#  ('Heard Island and McDonald Islands', None),
#  ('Norfolk Island', None),
#  ('Clipperton Island', None),
#  ('French Southern and Antarctic Lands', None),
#  ('Saint Barthelemy', None),
#  ('Saint Martin', None),
#  ('Cook Islands', None),
#  ('Niue', None),
#  ('Tokelau', None),
#  ('Bouvet Island', None),
#  ('Jan Mayen', None),
#  ('Svalbard', None),
#  ('Akrotiri', None),
#  ('British Indian Ocean Territory', None),
#  ('Dhekelia', None),
#  ('Falkland Islands (Islas Malvinas)', None),
#  ('Pitcairn Islands', None),
#  ('South Georgia and South Sandwich Islands', None),
#  ('Navassa Island', None),
#  ('Wake Island', None),
#  ('United States Pacific Island Wildlife Refuges', None),
#  ('Antarctica', None),
#  ('Paracel Islands', None),
#  ('Spratly Islands', None),
#  ('Western Sahara', None),
#  ('Arctic Ocean', None),
#  ('Atlantic Ocean', None),
#  ('Indian Ocean', None),
#  ('Pacific Ocean', None),
#  ('Southern Ocean', None),
#  ('World', None)]

# %% [markdown]
# There is a handy shortcut we can use in our queries which lets us skip the column names, and instead use the order in which the columns appear in the `SELECT` clause. In this instance, `migration_rate` is the second column in our `SELECT` clause so we can just use `2` instead of the column name:

# %%
# %%sql
# SELECT name, migration_rate FROM FACTS
# ORDER BY 2 desc;
# Out:
#  * sqlite:///factbook-join.db
#    sqlite:///factbook.db
# Done.
# [('Qatar', 22.39),
#  ('American Samoa', 21.13),
#  ('Micronesia, Federated States of', 20.93),
#  ('Syria', 19.79),
#  ('Tonga', 17.84),
#  ('British Virgin Islands', 17.28),
#  ('Luxembourg', 17.16),
#  ('Cayman Islands', 14.4),
#  ('Singapore', 14.05),
#  ('Nauru', 13.63),
#  ('Jordan', 13.24),
#  ('Bahrain', 13.09),
#  ('Maldives', 12.68),
#  ('United Arab Emirates', 12.36),
#  ('Anguilla', 12.18),
#  ('South Sudan', 11.47),
#  ('Turks and Caicos Islands', 9.94),
#  ('Samoa', 9.78),
#  ('Moldova', 9.67),
#  ('Cyprus', 9.48),
#  ('Saint Vincent and the Grenadines', 9.17),
#  ('Aruba', 8.92),
#  ('Sao Tome and Principe', 8.63),
#  ('Somalia', 8.49),
#  ('Saint Pierre and Miquelon', 8.49),
#  ('Spain', 8.31),
#  ('El Salvador', 8.28),
#  ('Puerto Rico', 8.15),
#  ('Guyana', 8.06),
#  ('San Marino', 8.03),
#  ('Libya', 7.8),
#  ('Virgin Islands', 7.67),
#  ('Lesotho', 7.36),
#  ('Norway', 7.25),
#  ('Northern Mariana Islands', 7.16),
#  ('Tuvalu', 6.81),
#  ('Fiji', 6.75),
#  ('Sint Maarten', 6.63),
#  ('Isle of Man', 6.56),
#  ('Guam', 6.34),
#  ('Lithuania', 6.27),
#  ('Latvia', 6.26),
#  ('Trinidad and Tobago', 6.25),
#  ('Djibouti', 6.06),
#  ('Greenland', 5.98),
#  ('Congo, Republic of the', 5.9),
#  ('Belgium', 5.87),
#  ('Armenia', 5.8),
#  ('Canada', 5.66),
#  ('Australia', 5.65),
#  ('Austria', 5.56),
#  ('Sweden', 5.42),
#  ('Dominica', 5.38),
#  ('Kyrgyzstan', 5.22),
#  ('Liechtenstein', 5.08),
#  ('Wallis and Futuna', 5.06),
#  ('Marshall Islands', 4.83),
#  ('Switzerland', 4.74),
#  ('Jamaica', 4.66),
#  ('Botswana', 4.56),
#  ('Iceland', 4.43),
#  ('Sudan', 4.29),
#  ('Italy', 4.1),
#  ('Ireland', 4.09),
#  ('New Caledonia', 4.01),
#  ('Nepal', 3.86),
#  ('Timor-Leste', 3.86),
#  ('United States', 3.86),
#  ('Monaco', 3.83),
#  ('Jersey', 3.76),
#  ('Cuba', 3.66),
#  ('Estonia', 3.6),
#  ('Chad', 3.45),
#  ('Macau', 3.37),
#  ('Morocco', 3.36),
#  ('Albania', 3.3),
#  ('Gibraltar', 3.28),
#  ('Grenada', 3.13),
#  ('Finland', 3.1),
#  ('Nicaragua', 3.0),
#  ('Saint Lucia', 2.93),
#  ('Kiribati', 2.87),
#  ('Sierra Leone', 2.77),
#  ('Haiti', 2.76),
#  ('Georgia', 2.7),
#  ('Portugal', 2.67),
#  ('United Kingdom', 2.54),
#  ('Comoros', 2.53),
#  ('Peru', 2.53),
#  ('European Union', 2.5),
#  ('Brunei', 2.43),
#  ('South Africa', 2.42),
#  ('Uzbekistan', 2.37),
#  ('Czech Republic', 2.33),
#  ('Greece', 2.32),
#  ('Guernsey', 2.32),
#  ('Mali', 2.26),
#  ('Ukraine', 2.25),
#  ('Israel', 2.24),
#  ('Antigua and Barbuda', 2.21),
#  ('New Zealand', 2.21),
#  ('Denmark', 2.2),
#  ('Turkey', 2.16),
#  ('Gambia, The', 2.12),
#  ('Philippines', 2.09),
#  ('Gabon', 2.03),
#  ('Ghana', 2.02),
#  ('Malta', 1.98),
#  ('Mozambique', 1.98),
#  ('Guatemala', 1.97),
#  ('Netherlands', 1.95),
#  ('Dominican Republic', 1.91),
#  ('Bermuda', 1.88),
#  ('Turkmenistan', 1.84),
#  ('Solomon Islands', 1.75),
#  ('Tunisia', 1.73),
#  ('Russia', 1.69),
#  ('Mexico', 1.68),
#  ('Hong Kong', 1.68),
#  ('Iraq', 1.62),
#  ('Senegal', 1.59),
#  ('Kuwait', 1.58),
#  ('Pakistan', 1.54),
#  ('Afghanistan', 1.51),
#  ('Vanuatu', 1.47),
#  ('Curacao', 1.4),
#  ('Croatia', 1.39),
#  ('Sri Lanka', 1.35),
#  ('Hungary', 1.33),
#  ('Germany', 1.24),
#  ('Saint Kitts and Nevis', 1.21),
#  ('Honduras', 1.16),
#  ('Indonesia', 1.16),
#  ('Tajikistan', 1.15),
#  ('Lebanon', 1.1),
#  ('France', 1.09),
#  ('Laos', 1.09),
#  ('Seychelles', 1.0),
#  ('Yemen', 1.0),
#  ('Algeria', 0.92),
#  ('Uruguay', 0.9),
#  ('Taiwan', 0.89),
#  ('Rwanda', 0.85),
#  ('Mongolia', 0.84),
#  ('French Polynesia', 0.84),
#  ('Costa Rica', 0.83),
#  ('Mauritania', 0.83),
#  ('Uganda', 0.74),
#  ('Palau', 0.71),
#  ('Belarus', 0.7),
#  ('Zambia', 0.68),
#  ('Colombia', 0.64),
#  ('Cabo Verde', 0.63),
#  ('Bolivia', 0.62),
#  ('Niger', 0.56),
#  ('Suriname', 0.56),
#  ('Saudi Arabia', 0.55),
#  ('Tanzania', 0.54),
#  ('Macedonia', 0.48),
#  ('Angola', 0.46),
#  ('Bangladesh', 0.46),
#  ('Poland', 0.46),
#  ('China', 0.44),
#  ('Oman', 0.43),
#  ('Kazakhstan', 0.41),
#  ('Bosnia and Herzegovina', 0.38),
#  ('Slovenia', 0.37),
#  ('Chile', 0.34),
#  ('Malaysia', 0.33),
#  ('Cambodia', 0.32),
#  ('Barbados', 0.3),
#  ('Vietnam', 0.3),
#  ('Bulgaria', 0.29),
#  ('Burma', 0.28),
#  ('Panama', 0.28),
#  ('Congo, Democratic Republic of the', 0.27),
#  ('Romania', 0.24),
#  ('Ethiopia', 0.22),
#  ('Kenya', 0.22),
#  ('Nigeria', 0.22),
#  ('Egypt', 0.19),
#  ('Cameroon', 0.15),
#  ('Brazil', 0.14),
#  ('Iran', 0.07),
#  ('Paraguay', 0.07),
#  ('India', 0.04),
#  ('Korea, North', 0.04),
#  ('Slovakia', 0.04),
#  ('Andorra', 0.0),
#  ('Argentina', 0.0),
#  ('Azerbaijan', 0.0),
#  ('Bahamas, The', 0.0),
#  ('Belize', 0.0),
#  ('Benin', 0.0),
#  ('Bhutan', 0.0),
#  ('Burkina Faso', 0.0),
#  ('Burundi', 0.0),
#  ('Central African Republic', 0.0),
#  ("Cote d'Ivoire", 0.0),
#  ('Ecuador', 0.0),
#  ('Equatorial Guinea', 0.0),
#  ('Eritrea', 0.0),
#  ('Guinea', 0.0),
#  ('Guinea-Bissau', 0.0),
#  ('Japan', 0.0),
#  ('Korea, South', 0.0),
#  ('Liberia', 0.0),
#  ('Madagascar', 0.0),
#  ('Malawi', 0.0),
#  ('Mauritius', 0.0),
#  ('Namibia', 0.0),
#  ('Papua New Guinea', 0.0),
#  ('Serbia', 0.0),
#  ('Swaziland', 0.0),
#  ('Thailand', 0.0),
#  ('Togo', 0.0),
#  ('Venezuela', 0.0),
#  ('Zimbabwe', 0.0),
#  ('Faroe Islands', 0.0),
#  ('Montserrat', 0.0),
#  ('Saint Helena, Ascension, and Tristan da Cunha', 0.0),
#  ('Gaza Strip', 0.0),
#  ('West Bank', 0.0),
#  ('Kosovo', None),
#  ('Montenegro', None),
#  ('Holy See (Vatican City)', None),
#  ('Ashmore and Cartier Islands', None),
#  ('Christmas Island', None),
#  ('Cocos (Keeling) Islands', None),
#  ('Coral Sea Islands', None),
#  ('Heard Island and McDonald Islands', None),
#  ('Norfolk Island', None),
#  ('Clipperton Island', None),
#  ('French Southern and Antarctic Lands', None),
#  ('Saint Barthelemy', None),
#  ('Saint Martin', None),
#  ('Cook Islands', None),
#  ('Niue', None),
#  ('Tokelau', None),
#  ('Bouvet Island', None),
#  ('Jan Mayen', None),
#  ('Svalbard', None),
#  ('Akrotiri', None),
#  ('British Indian Ocean Territory', None),
#  ('Dhekelia', None),
#  ('Falkland Islands (Islas Malvinas)', None),
#  ('Pitcairn Islands', None),
#  ('South Georgia and South Sandwich Islands', None),
#  ('Navassa Island', None),
#  ('Wake Island', None),
#  ('United States Pacific Island Wildlife Refuges', None),
#  ('Antarctica', None),
#  ('Paracel Islands', None),
#  ('Spratly Islands', None),
#  ('Western Sahara', None),
#  ('Arctic Ocean', None),
#  ('Atlantic Ocean', None),
#  ('Indian Ocean', None),
#  ('Pacific Ocean', None),
#  ('Southern Ocean', None),
#  ('World', None)]

# %% [markdown]
# You can use this shortcut in either the `ORDER BY` or `GROUP BY` clauses. Be mindful that you want to ensure your queries are still readable, so typing the full column name may be better for more complex queries.
#
# Let's use what we've learned to produce a list of the top 10 capital cities by population. Remember that `capital` is a boolean column containing `1` or `0`, depending on whether a city is a capital or not.
#
# Write a query that returns the 10 capital cities with the highest population ranked from biggest to smallest population.
# - You should include the following columns, in order:
#     - capital_city, the name of the city.
#     - country, the name of the country the city is from.
#     - population, the population of the city.
#
# Because we are not interested in countries from `facts` that don't have corresponding `cities` in cities, we should use an `INNER JOIN`.

# %%
# %%sql
# SELECT c.name capital_city,
#         f.name country,
#         c.population population
# FROM facts f
# INNER JOIN cities c ON c.facts_id = f.id
# WHERE c.capital = 1
# ORDER BY 3 DESC
# LIMIT 10;
# Out:
#  * sqlite:///factbook-join.db
#    sqlite:///factbook.db
# Done.
# [('Tokyo', 'Japan', 37217000),
#  ('New Delhi', 'India', 22654000),
#  ('Mexico City', 'Mexico', 20446000),
#  ('Beijing', 'China', 15594000),
#  ('Dhaka', 'Bangladesh', 15391000),
#  ('Buenos Aires', 'Argentina', 13528000),
#  ('Manila', 'Philippines', 11862000),
#  ('Moscow', 'Russia', 11621000),
#  ('Cairo', 'Egypt', 11169000),
#  ('Jakarta', 'Indonesia', 9769000)]

# %% [markdown]
# ## SUBQUERIES
#
# Subqueries can be used to substitute parts of queries, allowing us to find the answers to more complex questions. We can also join to the result of a subquery, just like we could a table.
#
# Here's an example of a using a join and a subquery to produce a table of countries and their capital cities.

# %%
# %%sql
# SELECT f.name country, c.name capital_city
# FROM facts f
# INNER JOIN (
#         SELECT * FROM cities
#         WHERE capital = 1
#         ) c ON c.facts_id = f.id
# LIMIT 10;
# Out:
#  * sqlite:///factbook-join.db
#    sqlite:///factbook.db
# Done.
# [('Aruba', 'Oranjestad'),
#  ('Antigua and Barbuda', "Saint John'S"),
#  ('United Arab Emirates', 'Abu Dhabi'),
#  ('Afghanistan', 'Kabul'),
#  ('Algeria', 'Algiers'),
#  ('Azerbaijan', 'Baku'),
#  ('Albania', 'Tirana'),
#  ('Armenia', 'Yerevan'),
#  ('Andorra', 'Andorra La Vella'),
#  ('Angola', 'Luanda')]

# %% [markdown]
# The important thing to remember is that the result of any subquery is always calculated first, so we read from the inside out.
#
# - The subquery, is calculated first. This simple query selects all columns from cities, filtering rows that are marked as capital cities by having a value for capital of 1.
# - The `INNER JOIN` joins the subquery result, aliased as `c`, to the `facts` table based on the `ON` clause.
# - Two columns are selected from the results of the join:
#     - f.name, aliased as country.
#     - c.name, aliased as capital_city.
# - The results are limited to the first 10 rows.
#
# Using this example as a model, we'll write a similar query to find the capital cities with populations of over 10 million.
#
# Using a join and a subquery, write a query that returns capital cities with populations of over 10 million ordered from largest to smallest. Include the following columns:
# - `capital_city` - the name of the city.
# - `country` - the name of the country the city is the capital of.
# - `population` - the population of the city.

# %%
# %%sql
# SELECT c.name capital_city, f.name country, c.population
# FROM facts f
# INNER JOIN (
#         SELECT * FROM cities
#         WHERE capital = 1 AND population > 10000000
#         ) c ON c.facts_id = f.id
# ORDER BY 3 DESC;
# Out:
#  * sqlite:///factbook-join.db
#    sqlite:///factbook.db
# Done.
# [('Tokyo', 'Japan', 37217000),
#  ('New Delhi', 'India', 22654000),
#  ('Mexico City', 'Mexico', 20446000),
#  ('Beijing', 'China', 15594000),
#  ('Dhaka', 'Bangladesh', 15391000),
#  ('Buenos Aires', 'Argentina', 13528000),
#  ('Manila', 'Philippines', 11862000),
#  ('Moscow', 'Russia', 11621000),
#  ('Cairo', 'Egypt', 11169000)]

# %% [markdown]
# ## Challenge - complex queries
#
# When you're writing complex queries with joins and subqueries, it helps to follow this process:
#
# - Think about what data you need in your final output
# - Work out which tables you'll need to join, and whether you will need to join to a subquery.
#     - If you need to join to a subquery, write the subquery first.
# - Then start writing your SELECT clause, followed by the join and any other clauses you will need.
# - Don't be afraid to write your query in steps, running it as you go— for instance you can run your subquery as a 'stand alone' query first to make sure it looks like you want before writing the outer query.
# We will be writing a query to `find the countries where the urban center (city) population is more than half of the country's total population`. For expected results, we rounded to six decimal places; however, when running your query, don't worry about rounding the `urban_pct` column.
#
# To help you out, the query you will write will include:
#
# - A join to a subquery.
# - A subquery to make a calculation.
# - An aggregate function.
# - A WHERE clause.
# - A CAST expression.
#
# The query should include:
#
# The following columns, in order:
# - `country`, the name of the country.
# - `urban_pop`, the sum of the population in major urban areas belonging to that country.
# - `total_pop`, the total population of the country.
# - `urban_pct`, the percentage of the population within urban areas, calculated by dividing urban_pop by total_pop.
#
# Only countries that have an `urban_pct` greater than 0.5.
#
# Rows should be sorted by `urban_pct` in ascending order.
#
# Define `urban_pop` within your subquery.

# %%
# %%sql
# SELECT f.name country,
#         c.urban_pop,
#         f.population total_pop,
#         (c.urban_pop / CAST(f.population AS FLOAT)) urban_pct
# FROM facts f
# INNER JOIN (
#         SELECT facts_id, SUM(population) urban_pop
#         FROM cities
#         GROUP BY 1
#         ) c ON c.facts_id = f.id
# WHERE urban_pct > .5
# ORDER BY 4 ASC;
# Out:
#  * sqlite:///factbook-join.db
#    sqlite:///factbook.db
# Done.
# [('Uruguay', 1672000, 3341893, 0.5003152404939356),
#  ('Congo, Republic of the', 2445000, 4755097, 0.5141850944365594),
#  ('Brunei', 241000, 429646, 0.5609269026128487),
#  ('New Caledonia', 157000, 271615, 0.5780240413821034),
#  ('Virgin Islands', 60000, 103574, 0.5792959623071428),
#  ('Falkland Islands (Islas Malvinas)', 2000, 3361, 0.5950609937518596),
#  ('Djibouti', 496000, 828324, 0.5987995035758954),
#  ('Australia', 13789000, 22751014, 0.6060828761302683),
#  ('Iceland', 206000, 331918, 0.6206352171319423),
#  ('Israel', 5226000, 8049314, 0.6492478737939655),
#  ('United Arab Emirates', 3903000, 5779760, 0.6752875551926032),
#  ('Puerto Rico', 2475000, 3598357, 0.6878139106264332),
#  ('Bahamas, The', 254000, 324597, 0.7825087724162577),
#  ('Kuwait', 2406000, 2788534, 0.8628189579183901),
#  ('Saint Pierre and Miquelon', 5000, 5657, 0.8838607035531201),
#  ('Guam', 169000, 161785, 1.0445962233828847),
#  ('Northern Mariana Islands', 56000, 52344, 1.0698456365581537),
#  ('American Samoa', 64000, 54343, 1.1777045801667188)]

# %% [markdown]
# In this mission we learned:
#
# - The difference between inner and left joins.
# - How to choose which join is appropriate for your task.
# - Using joins with subqueries, aggregate functions and other SQL techniques.
